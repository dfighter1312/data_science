# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Name: **Nguyễn Hoàng Dũng** (Hoang Dung Nguyen)
#
# Current occupation: Undergraduate Student
#
# Desired occupation: Data Scientist

# %% [markdown]
# *I am interested in data science because I want to swim on a zillions of data*

# %% [markdown]
# ### Calculating the simplest Math in the world

# %%
print(1 + 1)

# %% [markdown]
# ###### Bulleted list
#
# - Item
# - Item
# - Item
#
# ###### Numbered list
#
# 1. Item
# 1. Item
# 1. Item
#
# ###### Table
#
# 1 | 2 | 3
# --- | --- | ---
# A | B | C
# D | E | F
#
# ###### Code
#
# ```
# print(1+1)
# ```
